# %%
import os
import random
import cv2
import matplotlib.pyplot as plt

# %%
all_pics = os.listdir('NumBase')
random_pic = random.choice(all_pics)
random_pic = cv2.imread('NumBase' + '/' + random_pic)

# %%
plt.imshow(random_pic)

# %%
a = cv2.resize(random_pic, dsize=(96, 32))
plt.imshow(a)
